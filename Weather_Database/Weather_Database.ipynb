# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime

# %%
#Create a set of random lat and long combos
lats=np.random.uniform(low=-90, high=90, size=2000)
lngs=np.random.uniform(low=-180,high=180,size=2000)
lat_lngs=zip(lats,lngs)

#Add lats and lngs to list
coordinates=list(lat_lngs)

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count 
len(cities)
# Out:
# 750

# %%
#Import the requests library
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#Loop through cities
for i, city in enumerate(cities):
    
    #Group cities in sets of 100 for logging purposes
    if (i % 100 == 0 and i>=100):
        set_count +=1
        record_count=1
        
    #Create endpoint URL with each city
    city_url =  url + "&q=" + city.replace(" ","+")

    #Log the URL, record, and set numbers and city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    #Add 1 to record count
    record_count+=1
    
    #Run an API request for each of the cities
    try:
        #Parse the JSON and retrieve the data
        city_weather=requests.get(city_url).json()
        
        #Prase out the needed data
        city_lat=city_weather["coord"]["lat"]
        city_lng=city_weather["coord"]["lon"]
        city_max_temp=city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        #Append the city information to the city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description":city_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aykhal
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | umm lajj
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | alugan
# Processing Record 9 of Set 1 | honiara
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | yeletskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | ayacucho
# Processing Record 16 of Set 1 | tsienyane
# City not found. Skipping...
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | moussoro
# Processing Record 19 of Set 1 | eyl
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | alibag
# Processing Record 22 of Set 1 | natchez
# Processing Record 23 of Set 1 | krasnouralsk
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | san quintin
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | bira
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | antanifotsy
# Processing Record 31 of Set 1 | salinas
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | sault sainte marie
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | port-gentil
# Processing Record 36 of Set 1 | batticaloa
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | ostrovnoy
# Processing Record 39 of Set 1 | constitucion
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | carnarvon
# Processing Record 42 of Set 1 | healdsburg
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | honningsvag
# Processing Record 45 of Set 1 | carauari
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | valparaiso
# Processing Record 49 of Set 1 | margate
# Processing Record 50 of Set 1 | lethem
# Processing Record 51 of Set 1 | lebu
# Processing Record 52 of Set 1 | georgetown
# Processing Record 53 of Set 1 | vaini
# Processing Record 54 of Set 1 | north platte
# Processing Record 55 of Set 1 | san cristobal
# Processing Record 56 of Set 1 | haines junction
# Processing Record 57 of Set 1 | codrington
# Processing Record 58 of Set 1 | warrington
# Processing Record 59 of Set 1 | hermanus
# Processing Record 60 of Set 1 | victoria
# Processing Record 61 of Set 1 | conceicao do araguaia
# Processing Record 62 of Set 1 | korla
# Processing Record 63 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 64 of Set 1 | bogotol
# Processing Record 65 of Set 1 | hay river
# Processing Record 66 of Set 1 | ushuaia
# Processing Record 67 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 68 of Set 1 | torbay
# Processing Record 69 of Set 1 | ponta do sol
# Processing Record 70 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 71 of Set 1 | colares
# Processing Record 72 of Set 1 | metro
# Processing Record 73 of Set 1 | ilinskiy
# Processing Record 74 of Set 1 | tavda
# Processing Record 75 of Set 1 | cockburn town
# Processing Record 76 of Set 1 | toktogul
# Processing Record 77 of Set 1 | raudeberg
# Processing Record 78 of Set 1 | leiyang
# Processing Record 79 of Set 1 | novoilinsk
# Processing Record 80 of Set 1 | thinadhoo
# Processing Record 81 of Set 1 | bestobe
# Processing Record 82 of Set 1 | barrhead
# Processing Record 83 of Set 1 | talagang
# Processing Record 84 of Set 1 | thompson
# Processing Record 85 of Set 1 | saint-augustin
# Processing Record 86 of Set 1 | hirara
# Processing Record 87 of Set 1 | newbury
# Processing Record 88 of Set 1 | kysyl-syr
# Processing Record 89 of Set 1 | vestmanna
# Processing Record 90 of Set 1 | bandarbeyla
# Processing Record 91 of Set 1 | avarua
# Processing Record 92 of Set 1 | baijiantan
# Processing Record 93 of Set 1 | sao joao da barra
# Processing Record 94 of Set 1 | baykit
# Processing Record 95 of Set 1 | araguatins
# City not found. Skipping...
# Processing Record 96 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 97 of Set 1 | adrar
# Processing Record 98 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 99 of Set 1 | kruisfontein
# Processing Record 100 of Set 1 | mehamn
# Processing Record 1 of Set 2 | ayagoz
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | hambantota
# Processing Record 4 of Set 2 | launceston
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | port blair
# Processing Record 7 of Set 2 | hami
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | severo-kurilsk
# Processing Record 11 of Set 2 | tilichiki
# Processing Record 12 of Set 2 | cambyreta
# City not found. Skipping...
# Processing Record 13 of Set 2 | geraldton
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 2 | provideniya
# Processing Record 17 of Set 2 | hamilton
# Processing Record 18 of Set 2 | yumen
# Processing Record 19 of Set 2 | nuuk
# Processing Record 20 of Set 2 | jurm
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | dhidhdhoo
# Processing Record 24 of Set 2 | sola
# Processing Record 25 of Set 2 | bonavista
# Processing Record 26 of Set 2 | wagar
# Processing Record 27 of Set 2 | cabo san lucas
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | smolenka
# Processing Record 31 of Set 2 | mbandaka
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | otradnoye
# Processing Record 34 of Set 2 | xinmin
# Processing Record 35 of Set 2 | bubaque
# Processing Record 36 of Set 2 | teguldet
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | tautira
# Processing Record 39 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | kapaa
# Processing Record 42 of Set 2 | taganak
# Processing Record 43 of Set 2 | bilibino
# Processing Record 44 of Set 2 | poum
# Processing Record 45 of Set 2 | anadyr
# Processing Record 46 of Set 2 | coruripe
# Processing Record 47 of Set 2 | faanui
# Processing Record 48 of Set 2 | bowen
# Processing Record 49 of Set 2 | narsaq
# Processing Record 50 of Set 2 | bad frankenhausen
# Processing Record 51 of Set 2 | sakaiminato
# Processing Record 52 of Set 2 | matara
# Processing Record 53 of Set 2 | inongo
# Processing Record 54 of Set 2 | tripoli
# Processing Record 55 of Set 2 | komsomolskiy
# Processing Record 56 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 57 of Set 2 | yellowknife
# Processing Record 58 of Set 2 | bredasdorp
# Processing Record 59 of Set 2 | nguru
# Processing Record 60 of Set 2 | chokurdakh
# Processing Record 61 of Set 2 | chabahar
# Processing Record 62 of Set 2 | enid
# Processing Record 63 of Set 2 | port alfred
# Processing Record 64 of Set 2 | marsh harbour
# Processing Record 65 of Set 2 | kulu
# Processing Record 66 of Set 2 | konakovo
# Processing Record 67 of Set 2 | nhulunbuy
# Processing Record 68 of Set 2 | kostomuksha
# Processing Record 69 of Set 2 | noumea
# Processing Record 70 of Set 2 | cururupu
# Processing Record 71 of Set 2 | auki
# Processing Record 72 of Set 2 | monroe
# Processing Record 73 of Set 2 | noyabrsk
# Processing Record 74 of Set 2 | chuy
# Processing Record 75 of Set 2 | at-bashi
# Processing Record 76 of Set 2 | wanning
# Processing Record 77 of Set 2 | gigmoto
# Processing Record 78 of Set 2 | kiama
# Processing Record 79 of Set 2 | laureles
# Processing Record 80 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 81 of Set 2 | gornyak
# Processing Record 82 of Set 2 | wladyslawowo
# Processing Record 83 of Set 2 | port lincoln
# Processing Record 84 of Set 2 | badiraguato
# Processing Record 85 of Set 2 | hobart
# Processing Record 86 of Set 2 | mwense
# Processing Record 87 of Set 2 | aksu
# Processing Record 88 of Set 2 | itarema
# Processing Record 89 of Set 2 | asyut
# Processing Record 90 of Set 2 | kudahuvadhoo
# Processing Record 91 of Set 2 | praya
# Processing Record 92 of Set 2 | tsevie
# Processing Record 93 of Set 2 | tazovskiy
# Processing Record 94 of Set 2 | east london
# Processing Record 95 of Set 2 | kisangani
# Processing Record 96 of Set 2 | fortuna
# Processing Record 97 of Set 2 | ribeira grande
# Processing Record 98 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 99 of Set 2 | vostok
# Processing Record 100 of Set 2 | dikson
# Processing Record 1 of Set 3 | parabel
# Processing Record 2 of Set 3 | saint-esteve
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | diapaga
# Processing Record 5 of Set 3 | ibra
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | bilma
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | acarau
# Processing Record 12 of Set 3 | tessalit
# Processing Record 13 of Set 3 | beringovskiy
# Processing Record 14 of Set 3 | zhigansk
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | juan lacaze
# Processing Record 17 of Set 3 | lubon
# Processing Record 18 of Set 3 | hengyang
# Processing Record 19 of Set 3 | portland
# Processing Record 20 of Set 3 | qarchi gak
# Processing Record 21 of Set 3 | gamba
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | dingle
# Processing Record 24 of Set 3 | alofi
# Processing Record 25 of Set 3 | lengshuitan
# Processing Record 26 of Set 3 | kununurra
# Processing Record 27 of Set 3 | hasaki
# Processing Record 28 of Set 3 | barra do garcas
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | avera
# Processing Record 34 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 35 of Set 3 | urucara
# Processing Record 36 of Set 3 | le mans
# Processing Record 37 of Set 3 | maragogi
# Processing Record 38 of Set 3 | kodiak
# Processing Record 39 of Set 3 | qinzhou
# Processing Record 40 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 3 | flin flon
# Processing Record 42 of Set 3 | elat
# Processing Record 43 of Set 3 | bismarck
# Processing Record 44 of Set 3 | xichang
# Processing Record 45 of Set 3 | san andres
# Processing Record 46 of Set 3 | havelock
# Processing Record 47 of Set 3 | belyy yar
# Processing Record 48 of Set 3 | bengkulu
# Processing Record 49 of Set 3 | richards bay
# Processing Record 50 of Set 3 | mackay
# Processing Record 51 of Set 3 | broome
# Processing Record 52 of Set 3 | cayenne
# Processing Record 53 of Set 3 | tecpan
# Processing Record 54 of Set 3 | mahebourg
# Processing Record 55 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 56 of Set 3 | yanam
# Processing Record 57 of Set 3 | moorhead
# Processing Record 58 of Set 3 | tiznit
# Processing Record 59 of Set 3 | corowa
# Processing Record 60 of Set 3 | egvekinot
# Processing Record 61 of Set 3 | namatanai
# Processing Record 62 of Set 3 | melita
# Processing Record 63 of Set 3 | praia
# Processing Record 64 of Set 3 | constantine
# Processing Record 65 of Set 3 | venado tuerto
# Processing Record 66 of Set 3 | seoul
# Processing Record 67 of Set 3 | jalu
# Processing Record 68 of Set 3 | muros
# Processing Record 69 of Set 3 | khor
# Processing Record 70 of Set 3 | kamenka
# Processing Record 71 of Set 3 | bambous virieux
# Processing Record 72 of Set 3 | bintulu
# Processing Record 73 of Set 3 | kayerkan
# Processing Record 74 of Set 3 | aksay
# Processing Record 75 of Set 3 | birao
# Processing Record 76 of Set 3 | flinders
# Processing Record 77 of Set 3 | port hardy
# Processing Record 78 of Set 3 | chikoy
# City not found. Skipping...
# Processing Record 79 of Set 3 | ayame
# Processing Record 80 of Set 3 | miri
# Processing Record 81 of Set 3 | souillac
# Processing Record 82 of Set 3 | merauke
# Processing Record 83 of Set 3 | tomatlan
# Processing Record 84 of Set 3 | aswan
# Processing Record 85 of Set 3 | yima
# Processing Record 86 of Set 3 | vejalpur
# Processing Record 87 of Set 3 | nea zikhni
# City not found. Skipping...
# Processing Record 88 of Set 3 | ilulissat
# Processing Record 89 of Set 3 | batagay
# Processing Record 90 of Set 3 | touros
# Processing Record 91 of Set 3 | kochi
# Processing Record 92 of Set 3 | dir
# Processing Record 93 of Set 3 | maceio
# Processing Record 94 of Set 3 | qaanaaq
# Processing Record 95 of Set 3 | san juan
# Processing Record 96 of Set 3 | nanortalik
# Processing Record 97 of Set 3 | san-pedro
# Processing Record 98 of Set 3 | nalut
# Processing Record 99 of Set 3 | oranjestad
# Processing Record 100 of Set 3 | la palma
# Processing Record 1 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 2 of Set 4 | comodoro rivadavia
# Processing Record 3 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 4 | laguna
# Processing Record 5 of Set 4 | asau
# Processing Record 6 of Set 4 | leningradskiy
# Processing Record 7 of Set 4 | nome
# Processing Record 8 of Set 4 | pierre
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | vao
# Processing Record 11 of Set 4 | aklavik
# Processing Record 12 of Set 4 | saint augustine
# Processing Record 13 of Set 4 | ilorin
# Processing Record 14 of Set 4 | tura
# Processing Record 15 of Set 4 | kirkuk
# Processing Record 16 of Set 4 | aktau
# Processing Record 17 of Set 4 | mandan
# Processing Record 18 of Set 4 | micheweni
# Processing Record 19 of Set 4 | desbiens
# Processing Record 20 of Set 4 | ust-nera
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | santa catarina da serra
# Processing Record 23 of Set 4 | grindavik
# Processing Record 24 of Set 4 | wewak
# Processing Record 25 of Set 4 | kirensk
# Processing Record 26 of Set 4 | usinsk
# Processing Record 27 of Set 4 | kumluca
# Processing Record 28 of Set 4 | cabinda
# Processing Record 29 of Set 4 | boa vista
# Processing Record 30 of Set 4 | abonnema
# Processing Record 31 of Set 4 | kurilsk
# Processing Record 32 of Set 4 | sao felix do xingu
# Processing Record 33 of Set 4 | posse
# Processing Record 34 of Set 4 | kovernino
# Processing Record 35 of Set 4 | norman wells
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | lata
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | yerbogachen
# Processing Record 40 of Set 4 | tual
# Processing Record 41 of Set 4 | tame
# Processing Record 42 of Set 4 | sistranda
# Processing Record 43 of Set 4 | faya
# Processing Record 44 of Set 4 | yuzhno-sukhokumsk
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | melo
# Processing Record 47 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 4 | sibolga
# Processing Record 50 of Set 4 | jerusalem
# Processing Record 51 of Set 4 | bossembele
# City not found. Skipping...
# Processing Record 52 of Set 4 | awjilah
# Processing Record 53 of Set 4 | kahului
# Processing Record 54 of Set 4 | shelburne
# Processing Record 55 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 56 of Set 4 | los llanos de aridane
# Processing Record 57 of Set 4 | stornoway
# Processing Record 58 of Set 4 | igarka
# Processing Record 59 of Set 4 | coolum beach
# Processing Record 60 of Set 4 | davila
# Processing Record 61 of Set 4 | necochea
# Processing Record 62 of Set 4 | sorong
# Processing Record 63 of Set 4 | bairiki
# Processing Record 64 of Set 4 | sitka
# Processing Record 65 of Set 4 | lasa
# Processing Record 66 of Set 4 | puerto colombia
# Processing Record 67 of Set 4 | kutum
# Processing Record 68 of Set 4 | vestmannaeyjar
# Processing Record 69 of Set 4 | winnemucca
# Processing Record 70 of Set 4 | cabedelo
# Processing Record 71 of Set 4 | mount isa
# Processing Record 72 of Set 4 | lacombe
# Processing Record 73 of Set 4 | nemuro
# Processing Record 74 of Set 4 | kalmunai
# Processing Record 75 of Set 4 | san policarpo
# Processing Record 76 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 77 of Set 4 | odweyne
# Processing Record 78 of Set 4 | mecca
# Processing Record 79 of Set 4 | omsukchan
# Processing Record 80 of Set 4 | placido de castro
# Processing Record 81 of Set 4 | cao bang
# Processing Record 82 of Set 4 | caucaia
# Processing Record 83 of Set 4 | dillon
# Processing Record 84 of Set 4 | buta
# Processing Record 85 of Set 4 | sudogda
# Processing Record 86 of Set 4 | houma
# Processing Record 87 of Set 4 | kloulklubed
# Processing Record 88 of Set 4 | camocim
# Processing Record 89 of Set 4 | alyangula
# Processing Record 90 of Set 4 | jardim
# Processing Record 91 of Set 4 | brae
# Processing Record 92 of Set 4 | pisco
# Processing Record 93 of Set 4 | hofn
# Processing Record 94 of Set 4 | havoysund
# Processing Record 95 of Set 4 | la ronge
# Processing Record 96 of Set 4 | pangai
# Processing Record 97 of Set 4 | naze
# Processing Record 98 of Set 4 | isangel
# Processing Record 99 of Set 4 | port hedland
# Processing Record 100 of Set 4 | quatre cocos
# Processing Record 1 of Set 5 | manono
# Processing Record 2 of Set 5 | aksarka
# Processing Record 3 of Set 5 | maraba
# Processing Record 4 of Set 5 | lang son
# Processing Record 5 of Set 5 | pangnirtung
# Processing Record 6 of Set 5 | anloga
# Processing Record 7 of Set 5 | sirsa
# Processing Record 8 of Set 5 | caravelas
# Processing Record 9 of Set 5 | hurghada
# Processing Record 10 of Set 5 | rodrigues alves
# Processing Record 11 of Set 5 | rio grande
# Processing Record 12 of Set 5 | okahandja
# Processing Record 13 of Set 5 | bitung
# Processing Record 14 of Set 5 | harku
# Processing Record 15 of Set 5 | kavaratti
# Processing Record 16 of Set 5 | fartura
# Processing Record 17 of Set 5 | lorengau
# Processing Record 18 of Set 5 | kamaishi
# Processing Record 19 of Set 5 | okato
# Processing Record 20 of Set 5 | victor harbor
# Processing Record 21 of Set 5 | konstantinovsk
# Processing Record 22 of Set 5 | bathsheba
# Processing Record 23 of Set 5 | hovd
# Processing Record 24 of Set 5 | kuching
# Processing Record 25 of Set 5 | galle
# Processing Record 26 of Set 5 | pontianak
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | baillif
# Processing Record 29 of Set 5 | nouadhibou
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 5 | astana
# Processing Record 33 of Set 5 | hualmay
# Processing Record 34 of Set 5 | takoradi
# Processing Record 35 of Set 5 | burnie
# Processing Record 36 of Set 5 | gazanjyk
# Processing Record 37 of Set 5 | prado
# Processing Record 38 of Set 5 | roald
# Processing Record 39 of Set 5 | fort nelson
# Processing Record 40 of Set 5 | yulara
# Processing Record 41 of Set 5 | niksar
# Processing Record 42 of Set 5 | san pedro
# Processing Record 43 of Set 5 | jurmala
# Processing Record 44 of Set 5 | sosnovo-ozerskoye
# Processing Record 45 of Set 5 | mujiayingzi
# Processing Record 46 of Set 5 | alta
# Processing Record 47 of Set 5 | puerto salgar
# Processing Record 48 of Set 5 | cap malheureux
# Processing Record 49 of Set 5 | puerto varas
# Processing Record 50 of Set 5 | moron
# Processing Record 51 of Set 5 | balykshi
# Processing Record 52 of Set 5 | baglung
# Processing Record 53 of Set 5 | saint anthony
# Processing Record 54 of Set 5 | fairbanks
# Processing Record 55 of Set 5 | soyo
# Processing Record 56 of Set 5 | huayang
# Processing Record 57 of Set 5 | ilebo
# Processing Record 58 of Set 5 | rezekne
# Processing Record 59 of Set 5 | carutapera
# Processing Record 60 of Set 5 | sebeta
# Processing Record 61 of Set 5 | panjab
# Processing Record 62 of Set 5 | boende
# Processing Record 63 of Set 5 | christchurch
# Processing Record 64 of Set 5 | srednekolymsk
# Processing Record 65 of Set 5 | calvinia
# Processing Record 66 of Set 5 | blonduos
# City not found. Skipping...
# Processing Record 67 of Set 5 | dangriga
# Processing Record 68 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 69 of Set 5 | adre
# Processing Record 70 of Set 5 | bukama
# Processing Record 71 of Set 5 | paso de carrasco
# Processing Record 72 of Set 5 | san miguel el alto
# Processing Record 73 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 74 of Set 5 | cranbrook
# Processing Record 75 of Set 5 | waipawa
# Processing Record 76 of Set 5 | lieksa
# Processing Record 77 of Set 5 | half moon bay
# Processing Record 78 of Set 5 | tanout
# Processing Record 79 of Set 5 | bolivar
# Processing Record 80 of Set 5 | beloha
# Processing Record 81 of Set 5 | kihei
# Processing Record 82 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 83 of Set 5 | buraydah
# Processing Record 84 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 85 of Set 5 | awbari
# Processing Record 86 of Set 5 | tonantins
# Processing Record 87 of Set 5 | kayes
# Processing Record 88 of Set 5 | tubuala
# Processing Record 89 of Set 5 | sao filipe
# Processing Record 90 of Set 5 | ban bung
# Processing Record 91 of Set 5 | kokopo
# Processing Record 92 of Set 5 | nyurba
# Processing Record 93 of Set 5 | lavrentiya
# Processing Record 94 of Set 5 | jaguaribe
# Processing Record 95 of Set 5 | biak
# Processing Record 96 of Set 5 | ventspils
# Processing Record 97 of Set 5 | kavieng
# Processing Record 98 of Set 5 | taonan
# Processing Record 99 of Set 5 | ahipara
# Processing Record 100 of Set 5 | ambon
# Processing Record 1 of Set 6 | bludenz
# Processing Record 2 of Set 6 | belaya gora
# Processing Record 3 of Set 6 | kepanjen
# Processing Record 4 of Set 6 | westport
# Processing Record 5 of Set 6 | grandview
# Processing Record 6 of Set 6 | shuyskoye
# Processing Record 7 of Set 6 | kirksville
# Processing Record 8 of Set 6 | huarmey
# Processing Record 9 of Set 6 | akyab
# Processing Record 10 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 6 | sur
# Processing Record 12 of Set 6 | mitikas
# Processing Record 13 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 14 of Set 6 | kota belud
# Processing Record 15 of Set 6 | alihe
# Processing Record 16 of Set 6 | shcholkine
# City not found. Skipping...
# Processing Record 17 of Set 6 | coihaique
# Processing Record 18 of Set 6 | ramanuj ganj
# Processing Record 19 of Set 6 | shingu
# Processing Record 20 of Set 6 | karasjok
# Processing Record 21 of Set 6 | marzuq
# Processing Record 22 of Set 6 | imeni poliny osipenko
# Processing Record 23 of Set 6 | manaia
# Processing Record 24 of Set 6 | skibbereen
# Processing Record 25 of Set 6 | waingapu
# Processing Record 26 of Set 6 | vardo
# Processing Record 27 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 28 of Set 6 | ternate
# Processing Record 29 of Set 6 | geilo
# Processing Record 30 of Set 6 | vila velha
# Processing Record 31 of Set 6 | sterling
# Processing Record 32 of Set 6 | bengkalis
# City not found. Skipping...
# Processing Record 33 of Set 6 | churachandpur
# Processing Record 34 of Set 6 | the valley
# Processing Record 35 of Set 6 | emerald
# Processing Record 36 of Set 6 | svetlyy
# Processing Record 37 of Set 6 | sabalgarh
# Processing Record 38 of Set 6 | salym
# Processing Record 39 of Set 6 | kaspiyskiy
# Processing Record 40 of Set 6 | russell
# Processing Record 41 of Set 6 | fukue
# Processing Record 42 of Set 6 | chumikan
# Processing Record 43 of Set 6 | nadym
# Processing Record 44 of Set 6 | ballina
# Processing Record 45 of Set 6 | piacabucu
# Processing Record 46 of Set 6 | northam
# Processing Record 47 of Set 6 | valle nacional
# Processing Record 48 of Set 6 | marystown
# Processing Record 49 of Set 6 | vila franca do campo
# Processing Record 50 of Set 6 | kaoma
# Processing Record 51 of Set 6 | bull savanna
# Processing Record 52 of Set 6 | tahe
# Processing Record 53 of Set 6 | fianga
# City not found. Skipping...
# Processing Record 54 of Set 6 | denizli
# Processing Record 55 of Set 6 | pimentel
# Processing Record 56 of Set 6 | bemidji
# Processing Record 57 of Set 6 | teknaf
# Processing Record 58 of Set 6 | puerto el triunfo
# Processing Record 59 of Set 6 | agva
# City not found. Skipping...
# Processing Record 60 of Set 6 | tottori
# Processing Record 61 of Set 6 | sept-iles
# Processing Record 62 of Set 6 | qasigiannguit
# Processing Record 63 of Set 6 | haibara
# Processing Record 64 of Set 6 | lazaro cardenas
# Processing Record 65 of Set 6 | magadan
# Processing Record 66 of Set 6 | berdigestyakh
# Processing Record 67 of Set 6 | neiafu
# Processing Record 68 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 69 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 70 of Set 6 | opuwo
# Processing Record 71 of Set 6 | itacoatiara
# Processing Record 72 of Set 6 | kilembe
# Processing Record 73 of Set 6 | mokolo
# Processing Record 74 of Set 6 | nuremberg
# Processing Record 75 of Set 6 | duiwelskloof
# Processing Record 76 of Set 6 | laurel
# Processing Record 77 of Set 6 | limoux
# Processing Record 78 of Set 6 | nokaneng
# Processing Record 79 of Set 6 | mafeteng
# Processing Record 80 of Set 6 | tarecuato
# Processing Record 81 of Set 6 | verkhnevilyuysk
# Processing Record 82 of Set 6 | staryy nadym
# Processing Record 83 of Set 6 | tres arroyos
# Processing Record 84 of Set 6 | tigzirt
# Processing Record 85 of Set 6 | homer
# Processing Record 86 of Set 6 | tefe
# Processing Record 87 of Set 6 | kaeo
# Processing Record 88 of Set 6 | nurobod
# Processing Record 89 of Set 6 | mogocha
# Processing Record 90 of Set 6 | rocha
# Processing Record 91 of Set 6 | tyukalinsk
# Processing Record 92 of Set 6 | te anau
# Processing Record 93 of Set 6 | katsuura
# Processing Record 94 of Set 6 | aguimes
# Processing Record 95 of Set 6 | buchanan
# Processing Record 96 of Set 6 | hulan ergi
# Processing Record 97 of Set 6 | luderitz
# Processing Record 98 of Set 6 | karratha
# Processing Record 99 of Set 6 | talnakh
# Processing Record 100 of Set 6 | kodinsk
# Processing Record 1 of Set 7 | tianpeng
# Processing Record 2 of Set 7 | dwarka
# Processing Record 3 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 4 of Set 7 | taltal
# Processing Record 5 of Set 7 | mitchell
# Processing Record 6 of Set 7 | yeniseysk
# Processing Record 7 of Set 7 | sorland
# Processing Record 8 of Set 7 | mabaruma
# Processing Record 9 of Set 7 | novobelokatay
# Processing Record 10 of Set 7 | iqaluit
# Processing Record 11 of Set 7 | rantepao
# Processing Record 12 of Set 7 | tak bai
# Processing Record 13 of Set 7 | ketchikan
# Processing Record 14 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 7 | hendersonville
# Processing Record 16 of Set 7 | menongue
# Processing Record 17 of Set 7 | inhambane
# Processing Record 18 of Set 7 | phalombe
# Processing Record 19 of Set 7 | kisaran
# Processing Record 20 of Set 7 | lompoc
# Processing Record 21 of Set 7 | praia da vitoria
# Processing Record 22 of Set 7 | evensk
# Processing Record 23 of Set 7 | nuevitas
# Processing Record 24 of Set 7 | cap-aux-meules
# Processing Record 25 of Set 7 | fuxin
# Processing Record 26 of Set 7 | pemangkat
# Processing Record 27 of Set 7 | abu samrah
# Processing Record 28 of Set 7 | chadan
# Processing Record 29 of Set 7 | ous
# Processing Record 30 of Set 7 | malaya vishera
# Processing Record 31 of Set 7 | villapinzon
# Processing Record 32 of Set 7 | mayya
# Processing Record 33 of Set 7 | henties bay
# Processing Record 34 of Set 7 | shimoda
# Processing Record 35 of Set 7 | douentza
# Processing Record 36 of Set 7 | bodhan
# Processing Record 37 of Set 7 | kapuskasing
# Processing Record 38 of Set 7 | belogorsk
# Processing Record 39 of Set 7 | senmonorom
# City not found. Skipping...
# Processing Record 40 of Set 7 | boden
# Processing Record 41 of Set 7 | spanish town
# Processing Record 42 of Set 7 | port augusta
# Processing Record 43 of Set 7 | hobyo
# Processing Record 44 of Set 7 | zhezkazgan
# Processing Record 45 of Set 7 | itahari
# City not found. Skipping...
# Processing Record 46 of Set 7 | kyzyl-suu
# Processing Record 47 of Set 7 | gat
# Processing Record 48 of Set 7 | ambilobe
# Processing Record 49 of Set 7 | dumfries
# Processing Record 50 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 51 of Set 7 | alashtar
# City not found. Skipping...
# Processing Record 52 of Set 7 | tsentralnyy
# City not found. Skipping...
# Processing Record 53 of Set 7 | mirina
# City not found. Skipping...
# Processing Record 54 of Set 7 | imbituba
# Processing Record 55 of Set 7 | okha
# Processing Record 56 of Set 7 | baculin
# Processing Record 57 of Set 7 | luau
# Processing Record 58 of Set 7 | somain
# Processing Record 59 of Set 7 | atar
# Processing Record 60 of Set 7 | gimli
# Processing Record 61 of Set 7 | darhan
# Processing Record 62 of Set 7 | solnechnyy
# Processing Record 63 of Set 7 | mitsamiouli
# Processing Record 64 of Set 7 | deputatskiy
# Processing Record 65 of Set 7 | santa isabel do rio negro
# Processing Record 66 of Set 7 | itoman
# Processing Record 67 of Set 7 | menzelinsk
# Processing Record 68 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 69 of Set 7 | rehli
# Processing Record 70 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 71 of Set 7 | zaysan
# Processing Record 72 of Set 7 | maun
# Processing Record 73 of Set 7 | salta
# Processing Record 74 of Set 7 | bure
# Processing Record 75 of Set 7 | ola
# Processing Record 76 of Set 7 | balakhta
# Processing Record 77 of Set 7 | nyagan
# Processing Record 78 of Set 7 | kanel
# Processing Record 79 of Set 7 | narasannapeta
# Processing Record 80 of Set 7 | krasnik
# Processing Record 81 of Set 7 | luanda
# Processing Record 82 of Set 7 | north bend
# Processing Record 83 of Set 7 | vilyuysk
# Processing Record 84 of Set 7 | takaka
# Processing Record 85 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 86 of Set 7 | atasu
# Processing Record 87 of Set 7 | kaduna
# Processing Record 88 of Set 7 | nata
# Processing Record 89 of Set 7 | gizo
# Processing Record 90 of Set 7 | celestun
# Processing Record 91 of Set 7 | maicao
# Processing Record 92 of Set 7 | misratah
# Processing Record 93 of Set 7 | tartagal
# Processing Record 94 of Set 7 | kargopol
# Processing Record 95 of Set 7 | tecoanapa
# Processing Record 96 of Set 7 | wuchang
# Processing Record 97 of Set 7 | riosucio
# Processing Record 98 of Set 7 | lere
# Processing Record 99 of Set 7 | saraland
# Processing Record 100 of Set 7 | dongying
# Processing Record 1 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 2 of Set 8 | nanzhang
# Processing Record 3 of Set 8 | innisfail
# Processing Record 4 of Set 8 | trairi
# Processing Record 5 of Set 8 | port macquarie
# Processing Record 6 of Set 8 | mogadishu
# Processing Record 7 of Set 8 | skovorodino
# Processing Record 8 of Set 8 | novokizhinginsk
# Processing Record 9 of Set 8 | balaipungut
# Processing Record 10 of Set 8 | bridlington
# Processing Record 11 of Set 8 | doha
# Processing Record 12 of Set 8 | dudinka
# Processing Record 13 of Set 8 | tarboro
# Processing Record 14 of Set 8 | irmo
# Processing Record 15 of Set 8 | orissaare
# Processing Record 16 of Set 8 | porto novo
# Processing Record 17 of Set 8 | iquitos
# Processing Record 18 of Set 8 | conceicao da barra
# Processing Record 19 of Set 8 | chinsali
# Processing Record 20 of Set 8 | arlit
# Processing Record 21 of Set 8 | sandwick
# Processing Record 22 of Set 8 | fort-shevchenko
# Processing Record 23 of Set 8 | pirovskoye
# Processing Record 24 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 8 | fortuna foothills
# Processing Record 26 of Set 8 | am timan
# Processing Record 27 of Set 8 | benguela
# Processing Record 28 of Set 8 | calbuco
# Processing Record 29 of Set 8 | derzhavinsk
# Processing Record 30 of Set 8 | young
# Processing Record 31 of Set 8 | hoopstad
# Processing Record 32 of Set 8 | santiago del estero
# Processing Record 33 of Set 8 | san carlos de bariloche
# Processing Record 34 of Set 8 | semey
# Processing Record 35 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 8 | guerrero negro
# Processing Record 37 of Set 8 | bara
# Processing Record 38 of Set 8 | cozumel
# Processing Record 39 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 40 of Set 8 | powell river
# Processing Record 41 of Set 8 | ulan-ude
# Processing Record 42 of Set 8 | neyshabur
# Processing Record 43 of Set 8 | batemans bay
# Processing Record 44 of Set 8 | araguaina
# Processing Record 45 of Set 8 | paragould
# Processing Record 46 of Set 8 | wangqing
# Processing Record 47 of Set 8 | port shepstone
# Processing Record 48 of Set 8 | asfi
# Processing Record 49 of Set 8 | cassilandia
# Processing Record 50 of Set 8 | meridian
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert dictionaries to a Pandas Dataframe
city_data_df=pd.DataFrame(city_data)
#Reorder columns
new_column_order=["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Aykhal      RU  66.0000  111.5000     58.73        62          10
# 1        Atuona      PF  -9.8000 -139.0333     77.68        79          23
# 2     Hithadhoo      MV  -0.6000   73.0833     79.95        76          98
# 3      Umm Lajj      SA  25.0213   37.2685     87.17        70           0
# 4   New Norfolk      AU -42.7826  147.0587     53.92        79          40
# 5     Jamestown      US  42.0970  -79.2353     78.44        73           1
# 6  Punta Arenas      CL -53.1500  -70.9167     41.11        75          90
# 7        Alugan      PH  12.2188  125.4808     80.49        80         100
# 8       Honiara      SB  -9.4333  159.9500     83.88        69          91
# 9    Nikolskoye      RU  59.7035   30.7861     63.01        97          99
#
#    Wind Speed Current Description
# 0        2.21           clear sky
# 1       21.27          light rain
# 2        4.59     overcast clouds
# 3        3.83           clear sky
# 4        1.99    scattered clouds
# 5        5.75           clear sky
# 6       11.50     overcast clouds
# 7        3.49     overcast clouds
# 8        4.65     overcast clouds
# 9        4.92     overcast clouds

# %%
#Create output file (CSV) to store data
output_data_file="WeatherPy_Database.csv"

#Export the data
city_data_df.to_csv(output_data_file, index_label="City_ID")
